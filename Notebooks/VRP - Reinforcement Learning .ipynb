# %%
import numpy as np
from collections import defaultdict
from typing import List
import random

# %%
class VRPEnvironment:
    def __init__(self, num_vehicles, capacity, customers, distance_matrix):
        self.num_vehicles = num_vehicles
        self.capacity = capacity
        self.customers = customers
        self.distance_matrix = distance_matrix
        self.reset()
        
    def reset(self):
        self.vehicle_positions = [0] * self.num_vehicles
        self.customer_states = [tuple(self.customers)] * self.num_vehicles
        self.demands = [0] * self.num_vehicles
        self.total_distance = 0
        self.steps = 0
        
    def step(self, actions):
        rewards = [0] * self.num_vehicles
        next_customer_states = [None] * self.num_vehicles
        for i, action in enumerate(actions):
            if action < len(self.customer_states[i]):
                customer = self.customer_states[i][action]
                if self.demands[i] + customer[1] <= self.capacity:
                    self.demands[i] += customer[1]
                    rewards[i] -= self.distance_matrix[self.vehicle_positions[i]][customer[0]]
                    self.total_distance += self.distance_matrix[self.vehicle_positions[i]][customer[0]]
                    self.vehicle_positions[i] = customer[0]
                    next_customer_states[i] = self.customer_states[i][:action] + self.customer_states[i][action+1:]
        done = (len(next_customer_states[0]) == 0)
        state = tuple(self.vehicle_positions + [self.demands[0]] + [tuple(x) for x in next_customer_states])
        return state, sum(rewards), done

# %%
def train_vrp_agent(num_vehicles, capacity, customers, distance_matrix, num_episodes=1000, alpha=0.1, gamma=0.9, epsilon=0.1):
    num_customers = len(customers)

    # Initialize the Q-table with a shape that can hold all possible states and actions
    max_num_states = num_customers ** num_vehicles
    max_num_actions = capacity + 1
    q_table = np.zeros((max_num_states, max_num_actions))

    # Train the agent for the specified number of episodes
    for episode in range(num_episodes):
        # Reset the environment for each episode
        state = (0,)*num_vehicles
        total_reward = 0

        # Loop over all customers and choose an action for each vehicle
        for customer_index in range(num_customers):
            for vehicle_index in range(num_vehicles):
                # Convert the state to an index in the Q-table
                state_index = sum([state[i] * (num_customers ** i) for i in range(num_vehicles)])

                # Choose an action using epsilon-greedy exploration
                if random.uniform(0, 1) < epsilon:
                    action = random.randint(0, capacity)
                else:
                    action = np.argmax(q_table[state_index])

                # Calculate the reward for the chosen action
                customer = customers[customer_index]
                if action >= customer[1]:
                    reward = customer[1] - distance_matrix[state[vehicle_index]][customer_index]
                else:
                    reward = -100

                # Convert the next state to an index in the Q-table
                next_state = state[:vehicle_index] + (customer_index,) + state[vehicle_index+1:]
                next_state_index = sum([next_state[i] * (num_customers ** i) for i in range(num_vehicles)])

                # Update the Q-table using Q-learning
                q_table[state_index][action] += alpha * (reward + gamma * np.max(q_table[next_state_index]) - q_table[state_index][action])
                total_reward += reward

                # Move to the next state
                state = next_state

        # Print the total reward for the episode
        print("Episode:", episode, "Total reward:", total_reward)

    # Return the Q-table
    return q_table

# %%
def test_vrp_agent(q_table, num_vehicles, capacity, customers, distance_matrix, num_episodes=1000, alpha=0.1, gamma=0.9, epsilon=0.1):
    total_distance = 0
    # Loop through all vehicles
    for vehicle_idx in range(num_vehicles):
        load = 0
        distance = 0
        # Set the starting state for the current vehicle
        state = 0  # Starting depot node
        # Create a list of unvisited nodes (excluding the starting depot node)
        unvisited_nodes = list(range(1, len(customers)))
        # Loop until the route for the current vehicle is complete
        while True:
            # Choose an action for the current state using the Q-table
            q_values = q_table[state]
            valid_actions = np.nonzero(q_values)[0]
            action = random.choice(valid_actions)
            # Get the next state and reward based on the chosen action
            next_state = action
            reward = 0
            if next_state in unvisited_nodes:
                # Calculate the load and distance for the state transition
                load += customers[next_state]
                if load > capacity:
                    reward = -1  # Exceeding capacity is penalized
                    load -= customers[next_state]
                    next_state = state  # Stay at the current state
                else:
                    reward = 1  # Visiting a customer is rewarded
                    distance += distance_matrix[state][next_state]
                    unvisited_nodes.remove(next_state)
            else:
                # Penalize visiting an already visited node
                reward = -1
                next_state = state  # Stay at the current state
            # Update the Q-table for the current state and action
            old_value = q_table[state, action]
            next_max = np.max(q_table[next_state])
            new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
            q_table[state, action] = new_value
            # Move to the next state
            state = next_state
            # Check if the route is complete
            if not unvisited_nodes:
                # Return to the starting depot node
                distance += distance_matrix[state][0]
                break
            # Check if the current state and action are invalid
            if state >= len(distance_matrix) or next_state >= len(distance_matrix[state]):
                distance = float('inf')
                break
        # Add the distance traveled by the current vehicle to the total distance
        total_distance += distance
    return total_distance

# %%
num_vehicles = 2
capacity = 100
customers = [(1, 20), (2, 30), (3, 50), (4, 10), (5, 40)]
distance_matrix = [
    [0, 10, 20, 5, 15],
    [10, 0, 15, 20, 25],
    [20, 15, 0, 10, 30],
    [5, 20, 10, 0, 10],
    [15, 25, 30, 10, 0],
]

# %%
q_table = train_vrp_agent(num_vehicles, capacity, customers, distance_matrix, num_episodes=1000)
# Out:
# Episode: 0 Total reward: -1000
# Episode: 1 Total reward: -635
# Episode: 2 Total reward: -865
# Episode: 3 Total reward: -735
# Episode: 4 Total reward: -500
# Episode: 5 Total reward: -600
# Episode: 6 Total reward: -730
# Episode: 7 Total reward: -260
# Episode: 8 Total reward: -360
# Episode: 9 Total reward: -260
# Episode: 10 Total reward: -360
# Episode: 11 Total reward: -140
# Episode: 12 Total reward: -140
# Episode: 13 Total reward: -40
# Episode: 14 Total reward: 80
# Episode: 15 Total reward: -55
# Episode: 16 Total reward: 80
# Episode: 17 Total reward: 210
# Episode: 18 Total reward: 210
# Episode: 19 Total reward: 210
# Episode: 20 Total reward: 210
# Episode: 21 Total reward: 210
# Episode: 22 Total reward: 80
# Episode: 23 Total reward: 210
# Episode: 24 Total reward: 210
# Episode: 25 Total reward: 210
# Episode: 26 Total reward: 210
# Episode: 27 Total reward: 210
# Episode: 28 Total reward: 210
# Episode: 29 Total reward: 75
# Episode: 30 Total reward: 210
# Episode: 31 Total reward: 80
# Episode: 32 Total reward: 210
# Episode: 33 Total reward: 210
# Episode: 34 Total reward: 210
# Episode: 35 Total reward: 80
# Episode: 36 Total reward: 210
# Episode: 37 Total reward: 210
# Episode: 38 Total reward: -45
# Episode: 39 Total reward: 210
# Episode: 40 Total reward: 75
# Episode: 41 Total reward: 210
# Episode: 42 Total reward: 210
# Episode: 43 Total reward: 75
# Episode: 44 Total reward: 210
# Episode: 45 Total reward: 210
# Episode: 46 Total reward: 75
# Episode: 47 Total reward: 75
# Episode: 48 Total reward: 210
# Episode: 49 Total reward: 210
# Episode: 50 Total reward: 75
# Episode: 51 Total reward: 210
# Episode: 52 Total reward: 210
# Episode: 53 Total reward: 90
# Episode: 54 Total reward: 75
# Episode: 55 Total reward: 210
# Episode: 56 Total reward: 210
# Episode: 57 Total reward: 75
# Episode: 58 Total reward: 210
# Episode: 59 Total reward: 210
# Episode: 60 Total reward: 210
# Episode: 61 Total reward: 210
# Episode: 62 Total reward: 80
# Episode: 63 Total reward: 210
# Episode: 64 Total reward: 210
# Episode: 65 Total reward: 210
# Episode: 66 Total reward: 210
# Episode: 67 Total reward: 210
# Episode: 68 Total reward: 210
# Episode: 69 Total reward: 80
# Episode: 70 Total reward: 80
# Episode: 71 Total reward: 210
# Episode: 72 Total reward: 210
# Episode: 73 Total reward: 210
# Episode: 74 Total reward: 210
# Episode: 75 Total reward: 210
# Episode: 76 Total reward: 210
# Episode: 77 Total reward: 210
# Episode: 78 Total reward: 210
# Episode: 79 Total reward: 90
# Episode: 80 Total reward: 210
# Episode: 81 Total reward: 210
# Episode: 82 Total reward: 210
# Episode: 83 Total reward: 210
# Episode: 84 Total reward: -60
# Episode: 85 Total reward: 80
# Episode: 86 Total reward: 75
# Episode: 87 Total reward: 210
# Episode: 88 Total reward: 210
# Episode: 89 Total reward: 75
# Episode: 90 Total reward: 210
# Episode: 91 Total reward: 210
# Episode: 92 Total reward: 210
# Episode: 93 Total reward: 210
# Episode: 94 Total reward: 210
# Episode: 95 Total reward: 75
# Episode: 96 Total reward: 210
# Episode: 97 Total reward: 210
# Episode: 98 Total reward: 210
# Episode: 99 Total reward: 210
# Episode: 100 Total reward: 210
# Episode: 101 Total reward: 210
# Episode: 102 Total reward: 210
# Episode: 103 Total reward: 210
# Episode: 104 Total reward: 210
# Episode: 105 Total reward: 210
# Episode: 106 Total reward: 210
# Episode: 107 Total reward: 90
# Episode: 108 Total reward: 210
# Episode: 109 Total reward: 210
# Episode: 110 Total reward: 210
# Episode: 111 Total reward: 210
# Episode: 112 Total reward: -60
# Episode: 113 Total reward: 90
# Episode: 114 Total reward: 210
# Episode: 115 Total reward: 210
# Episode: 116 Total reward: 210
# Episode: 117 Total reward: 210
# Episode: 118 Total reward: 210
# Episode: 119 Total reward: 210
# Episode: 120 Total reward: 210
# Episode: 121 Total reward: 210
# Episode: 122 Total reward: 210
# Episode: 123 Total reward: 210
# Episode: 124 Total reward: 210
# Episode: 125 Total reward: 75
# Episode: 126 Total reward: 210
# Episode: 127 Total reward: 75
# Episode: 128 Total reward: 210
# Episode: 129 Total reward: 80
# Episode: 130 Total reward: 210
# Episode: 131 Total reward: 75
# Episode: 132 Total reward: 210
# Episode: 133 Total reward: 210
# Episode: 134 Total reward: 210
# Episode: 135 Total reward: 210
# Episode: 136 Total reward: 80
# Episode: 137 Total reward: 210
# Episode: 138 Total reward: 210
# Episode: 139 Total reward: 210
# Episode: 140 Total reward: 210
# Episode: 141 Total reward: 210
# Episode: 142 Total reward: 110
# Episode: 143 Total reward: 210
# Episode: 144 Total reward: 90
# Episode: 145 Total reward: 210
# Episode: 146 Total reward: 210
# Episode: 147 Total reward: 210
# Episode: 148 Total reward: 90
# Episode: 149 Total reward: 210
# Episode: 150 Total reward: 210
# Episode: 151 Total reward: 210
# Episode: 152 Total reward: 210
# Episode: 153 Total reward: 210
# Episode: 154 Total reward: -45
# Episode: 155 Total reward: 210
# Episode: 156 Total reward: 80
# Episode: 157 Total reward: 210
# Episode: 158 Total reward: 210
# Episode: 159 Total reward: 210
# Episode: 160 Total reward: 80
# Episode: 161 Total reward: 210
# Episode: 162 Total reward: 210
# Episode: 163 Total reward: 210
# Episode: 164 Total reward: 80
# Episode: 165 Total reward: 210
# Episode: 166 Total reward: 90
# Episode: 167 Total reward: -45
# Episode: 168 Total reward: 90
# Episode: 169 Total reward: 210
# Episode: 170 Total reward: 110
# Episode: 171 Total reward: 210
# Episode: 172 Total reward: 210
# Episode: 173 Total reward: 210
# Episode: 174 Total reward: 80
# Episode: 175 Total reward: 210
# Episode: 176 Total reward: 210
# Episode: 177 Total reward: 210
# Episode: 178 Total reward: 210
# Episode: 179 Total reward: 210
# Episode: 180 Total reward: 210
# Episode: 181 Total reward: 210
# Episode: 182 Total reward: 210
# Episode: 183 Total reward: 210
# Episode: 184 Total reward: 210
# Episode: 185 Total reward: 75
# Episode: 186 Total reward: 210
# Episode: 187 Total reward: 210
# Episode: 188 Total reward: 210
# Episode: 189 Total reward: 210
# Episode: 190 Total reward: 210
# Episode: 191 Total reward: 210
# Episode: 192 Total reward: 210
# Episode: 193 Total reward: 210
# Episode: 194 Total reward: 90
# Episode: 195 Total reward: 210
# Episode: 196 Total reward: 80
# Episode: 197 Total reward: 210
# Episode: 198 Total reward: 210
# Episode: 199 Total reward: 210
# Episode: 200 Total reward: 80
# Episode: 201 Total reward: 75
# Episode: 202 Total reward: 210
# Episode: 203 Total reward: 210
# Episode: 204 Total reward: 210
# Episode: 205 Total reward: 210
# Episode: 206 Total reward: 210
# Episode: 207 Total reward: 210
# Episode: 208 Total reward: 90
# Episode: 209 Total reward: 75
# Episode: 210 Total reward: 75
# Episode: 211 Total reward: 210
# Episode: 212 Total reward: 210
# Episode: 213 Total reward: 210
# Episode: 214 Total reward: 75
# Episode: 215 Total reward: 210
# Episode: 216 Total reward: 210
# Episode: 217 Total reward: 210
# Episode: 218 Total reward: 210
# Episode: 219 Total reward: 210
# Episode: 220 Total reward: 210
# Episode: 221 Total reward: 210
# Episode: 222 Total reward: 210
# Episode: 223 Total reward: 90
# Episode: 224 Total reward: 210
# Episode: 225 Total reward: 75
# Episode: 226 Total reward: 210
# Episode: 227 Total reward: 210
# Episode: 228 Total reward: 210
# Episode: 229 Total reward: 90
# Episode: 230 Total reward: 75
# Episode: 231 Total reward: 210
# Episode: 232 Total reward: 75
# Episode: 233 Total reward: 210
# Episode: 234 Total reward: 80
# Episode: 235 Total reward: 210
# Episode: 236 Total reward: 80
# Episode: 237 Total reward: 210
# Episode: 238 Total reward: 210
# Episode: 239 Total reward: 210
# Episode: 240 Total reward: 210
# Episode: 241 Total reward: 75
# Episode: 242 Total reward: 210
# Episode: 243 Total reward: 210
# Episode: 244 Total reward: 210
# Episode: 245 Total reward: 210
# Episode: 246 Total reward: 210
# Episode: 247 Total reward: 210
# Episode: 248 Total reward: 90
# Episode: 249 Total reward: 210
# Episode: 250 Total reward: 210
# Episode: 251 Total reward: 210
# Episode: 252 Total reward: 210
# Episode: 253 Total reward: 210
# Episode: 254 Total reward: 80
# Episode: 255 Total reward: 210
# Episode: 256 Total reward: 90
# Episode: 257 Total reward: 90
# Episode: 258 Total reward: 210
# Episode: 259 Total reward: 80
# Episode: 260 Total reward: -55
# Episode: 261 Total reward: 210
# Episode: 262 Total reward: 210
# Episode: 263 Total reward: 210
# Episode: 264 Total reward: 210
# Episode: 265 Total reward: 210
# Episode: 266 Total reward: 210
# Episode: 267 Total reward: 90
# Episode: 268 Total reward: 210
# Episode: 269 Total reward: 210
# Episode: 270 Total reward: 210
# Episode: 271 Total reward: 210
# Episode: 272 Total reward: 210
# Episode: 273 Total reward: 210
# Episode: 274 Total reward: 75
# Episode: 275 Total reward: 210
# Episode: 276 Total reward: 210
# Episode: 277 Total reward: 90
# Episode: 278 Total reward: 75
# Episode: 279 Total reward: 210
# Episode: 280 Total reward: 90
# Episode: 281 Total reward: 75
# Episode: 282 Total reward: 90
# Episode: 283 Total reward: 210
# Episode: 284 Total reward: 210
# Episode: 285 Total reward: 210
# Episode: 286 Total reward: 210
# Episode: 287 Total reward: 210
# Episode: 288 Total reward: 75
# Episode: 289 Total reward: 210
# Episode: 290 Total reward: 210
# Episode: 291 Total reward: 80
# Episode: 292 Total reward: 210
# Episode: 293 Total reward: 210
# Episode: 294 Total reward: 90
# Episode: 295 Total reward: 80
# Episode: 296 Total reward: 210
# Episode: 297 Total reward: 210
# Episode: 298 Total reward: 210
# Episode: 299 Total reward: 90
# Episode: 300 Total reward: 210
# Episode: 301 Total reward: 80
# Episode: 302 Total reward: 210
# Episode: 303 Total reward: 210
# Episode: 304 Total reward: 90
# Episode: 305 Total reward: 80
# Episode: 306 Total reward: 90
# Episode: 307 Total reward: 210
# Episode: 308 Total reward: 210
# Episode: 309 Total reward: 80
# Episode: 310 Total reward: 80
# Episode: 311 Total reward: 210
# Episode: 312 Total reward: -30
# Episode: 313 Total reward: 80
# Episode: 314 Total reward: 210
# Episode: 315 Total reward: 210
# Episode: 316 Total reward: 210
# Episode: 317 Total reward: 210
# Episode: 318 Total reward: 210
# Episode: 319 Total reward: 210
# Episode: 320 Total reward: 80
# Episode: 321 Total reward: 210
# Episode: 322 Total reward: 210
# Episode: 323 Total reward: 210
# Episode: 324 Total reward: 75
# Episode: 325 Total reward: 210
# Episode: 326 Total reward: 210
# Episode: 327 Total reward: 210
# Episode: 328 Total reward: 210
# Episode: 329 Total reward: 80
# Episode: 330 Total reward: 75
# Episode: 331 Total reward: 210
# Episode: 332 Total reward: 80
# Episode: 333 Total reward: 90
# Episode: 334 Total reward: 75
# Episode: 335 Total reward: 210
# Episode: 336 Total reward: 210
# Episode: 337 Total reward: 75
# Episode: 338 Total reward: 110
# Episode: 339 Total reward: 80
# Episode: 340 Total reward: 210
# Episode: 341 Total reward: 210
# Episode: 342 Total reward: 210
# Episode: 343 Total reward: 210
# Episode: 344 Total reward: 210
# Episode: 345 Total reward: 210
# Episode: 346 Total reward: 210
# Episode: 347 Total reward: 210
# Episode: 348 Total reward: 210
# Episode: 349 Total reward: 210
# Episode: 350 Total reward: 210
# Episode: 351 Total reward: 90
# Episode: 352 Total reward: 210
# Episode: 353 Total reward: 210
# Episode: 354 Total reward: 210
# Episode: 355 Total reward: 80
# Episode: 356 Total reward: 210
# Episode: 357 Total reward: 80
# Episode: 358 Total reward: 75
# Episode: 359 Total reward: 210
# Episode: 360 Total reward: 210
# Episode: 361 Total reward: 210
# Episode: 362 Total reward: 210
# Episode: 363 Total reward: 210
# Episode: 364 Total reward: 210
# Episode: 365 Total reward: 210
# Episode: 366 Total reward: 210
# Episode: 367 Total reward: 80
# Episode: 368 Total reward: 210
# Episode: 369 Total reward: -40
# Episode: 370 Total reward: 210
# Episode: 371 Total reward: 90
# Episode: 372 Total reward: 210
# Episode: 373 Total reward: 210
# Episode: 374 Total reward: 90
# Episode: 375 Total reward: 210
# Episode: 376 Total reward: 210
# Episode: 377 Total reward: 210
# Episode: 378 Total reward: 110
# Episode: 379 Total reward: 90
# Episode: 380 Total reward: 210
# Episode: 381 Total reward: 210
# Episode: 382 Total reward: 210
# Episode: 383 Total reward: 210
# Episode: 384 Total reward: 210
# Episode: 385 Total reward: 210
# Episode: 386 Total reward: -55
# Episode: 387 Total reward: 210
# Episode: 388 Total reward: 90
# Episode: 389 Total reward: 210
# Episode: 390 Total reward: 210
# Episode: 391 Total reward: 90
# Episode: 392 Total reward: 210
# Episode: 393 Total reward: 210
# Episode: 394 Total reward: 90
# Episode: 395 Total reward: 80
# Episode: 396 Total reward: 80
# Episode: 397 Total reward: 210
# Episode: 398 Total reward: 210
# Episode: 399 Total reward: 210
# Episode: 400 Total reward: 210
# Episode: 401 Total reward: 210
# Episode: 402 Total reward: 210
# Episode: 403 Total reward: 210
# Episode: 404 Total reward: 210
# Episode: 405 Total reward: 80
# Episode: 406 Total reward: 90
# Episode: 407 Total reward: 210
# Episode: 408 Total reward: 210
# Episode: 409 Total reward: 75
# Episode: 410 Total reward: 210
# Episode: 411 Total reward: 75
# Episode: 412 Total reward: 210
# Episode: 413 Total reward: 75
# Episode: 414 Total reward: 80
# Episode: 415 Total reward: 210
# Episode: 416 Total reward: 80
# Episode: 417 Total reward: 90
# Episode: 418 Total reward: 210
# Episode: 419 Total reward: 80
# Episode: 420 Total reward: 210
# Episode: 421 Total reward: 210
# Episode: 422 Total reward: 75
# Episode: 423 Total reward: 210
# Episode: 424 Total reward: 210
# Episode: 425 Total reward: 210
# Episode: 426 Total reward: 210
# Episode: 427 Total reward: 210
# Episode: 428 Total reward: 210
# Episode: 429 Total reward: 210
# Episode: 430 Total reward: 210
# Episode: 431 Total reward: 210
# Episode: 432 Total reward: 210
# Episode: 433 Total reward: 210
# Episode: 434 Total reward: 210
# Episode: 435 Total reward: 75
# Episode: 436 Total reward: 75
# Episode: 437 Total reward: 210
# Episode: 438 Total reward: 210
# Episode: 439 Total reward: 210
# Episode: 440 Total reward: 210
# Episode: 441 Total reward: 210
# Episode: 442 Total reward: 80
# Episode: 443 Total reward: 210
# Episode: 444 Total reward: 210
# Episode: 445 Total reward: 75
# Episode: 446 Total reward: 210
# Episode: 447 Total reward: 80
# Episode: 448 Total reward: 210
# Episode: 449 Total reward: 90
# Episode: 450 Total reward: 210
# Episode: 451 Total reward: 210
# Episode: 452 Total reward: 210
# Episode: 453 Total reward: 210
# Episode: 454 Total reward: -40
# Episode: 455 Total reward: 210
# Episode: 456 Total reward: 210
# Episode: 457 Total reward: 210
# Episode: 458 Total reward: 210
# Episode: 459 Total reward: 75
# Episode: 460 Total reward: 210
# Episode: 461 Total reward: 75
# Episode: 462 Total reward: 210
# Episode: 463 Total reward: 75
# Episode: 464 Total reward: 210
# Episode: 465 Total reward: 80
# Episode: 466 Total reward: 210
# Episode: 467 Total reward: 210
# Episode: 468 Total reward: 210
# Episode: 469 Total reward: 210
# Episode: 470 Total reward: 210
# Episode: 471 Total reward: 210
# Episode: 472 Total reward: 90
# Episode: 473 Total reward: 210
# Episode: 474 Total reward: 210
# Episode: 475 Total reward: 210
# Episode: 476 Total reward: 210
# Episode: 477 Total reward: 210
# Episode: 478 Total reward: 210
# Episode: 479 Total reward: 210
# Episode: 480 Total reward: 210
# Episode: 481 Total reward: 210
# Episode: 482 Total reward: 210
# Episode: 483 Total reward: 210
# Episode: 484 Total reward: 210
# Episode: 485 Total reward: 80
# Episode: 486 Total reward: 210
# Episode: 487 Total reward: 80
# Episode: 488 Total reward: -30
# Episode: 489 Total reward: 210
# Episode: 490 Total reward: 210
# Episode: 491 Total reward: 210
# Episode: 492 Total reward: 80
# Episode: 493 Total reward: 210
# Episode: 494 Total reward: 210
# Episode: 495 Total reward: 90
# Episode: 496 Total reward: 90
# Episode: 497 Total reward: 90
# Episode: 498 Total reward: 90
# Episode: 499 Total reward: 210
# Episode: 500 Total reward: 75
# Episode: 501 Total reward: 210
# Episode: 502 Total reward: 210
# Episode: 503 Total reward: 210
# Episode: 504 Total reward: 110
# Episode: 505 Total reward: 90
# Episode: 506 Total reward: 90
# Episode: 507 Total reward: 210
# Episode: 508 Total reward: 210
# Episode: 509 Total reward: 210
# Episode: 510 Total reward: 210
# Episode: 511 Total reward: 90
# Episode: 512 Total reward: 210
# Episode: 513 Total reward: 210
# Episode: 514 Total reward: 210
# Episode: 515 Total reward: 210
# Episode: 516 Total reward: 210
# Episode: 517 Total reward: 210
# Episode: 518 Total reward: -55
# Episode: 519 Total reward: 80
# Episode: 520 Total reward: 210
# Episode: 521 Total reward: 210
# Episode: 522 Total reward: 210
# Episode: 523 Total reward: 210
# Episode: 524 Total reward: 210
# Episode: 525 Total reward: 75
# Episode: 526 Total reward: 210
# Episode: 527 Total reward: 80
# Episode: 528 Total reward: 210
# Episode: 529 Total reward: 210
# Episode: 530 Total reward: 210
# Episode: 531 Total reward: 210
# Episode: 532 Total reward: 80
# Episode: 533 Total reward: 210
# Episode: 534 Total reward: 210
# Episode: 535 Total reward: 210
# Episode: 536 Total reward: 210
# Episode: 537 Total reward: 210
# Episode: 538 Total reward: 210
# Episode: 539 Total reward: 210
# Episode: 540 Total reward: 210
# Episode: 541 Total reward: 210
# Episode: 542 Total reward: 210
# Episode: 543 Total reward: 90
# Episode: 544 Total reward: 210
# Episode: 545 Total reward: 110
# Episode: 546 Total reward: 210
# Episode: 547 Total reward: 210
# Episode: 548 Total reward: 210
# Episode: 549 Total reward: 210
# Episode: 550 Total reward: 80
# Episode: 551 Total reward: 210
# Episode: 552 Total reward: 210
# Episode: 553 Total reward: 210
# Episode: 554 Total reward: 210
# Episode: 555 Total reward: 210
# Episode: 556 Total reward: 90
# Episode: 557 Total reward: 90
# Episode: 558 Total reward: 210
# Episode: 559 Total reward: 210
# Episode: 560 Total reward: 210
# Episode: 561 Total reward: 210
# Episode: 562 Total reward: 90
# Episode: 563 Total reward: 210
# Episode: 564 Total reward: 210
# Episode: 565 Total reward: 210
# Episode: 566 Total reward: 90
# Episode: 567 Total reward: 210
# Episode: 568 Total reward: 210
# Episode: 569 Total reward: 210
# Episode: 570 Total reward: 210
# Episode: 571 Total reward: 210
# Episode: 572 Total reward: 210
# Episode: 573 Total reward: 90
# Episode: 574 Total reward: -25
# Episode: 575 Total reward: 210
# Episode: 576 Total reward: 210
# Episode: 577 Total reward: 210
# Episode: 578 Total reward: 210
# Episode: 579 Total reward: 210
# Episode: 580 Total reward: 90
# Episode: 581 Total reward: 75
# Episode: 582 Total reward: 210
# Episode: 583 Total reward: 210
# Episode: 584 Total reward: 210
# Episode: 585 Total reward: 210
# Episode: 586 Total reward: 90
# Episode: 587 Total reward: 210
# Episode: 588 Total reward: 210
# Episode: 589 Total reward: 210
# Episode: 590 Total reward: 90
# Episode: 591 Total reward: 210
# Episode: 592 Total reward: 210
# Episode: 593 Total reward: 210
# Episode: 594 Total reward: 210
# Episode: 595 Total reward: 210
# Episode: 596 Total reward: 210
# Episode: 597 Total reward: 210
# Episode: 598 Total reward: 210
# Episode: 599 Total reward: 210
# Episode: 600 Total reward: 210
# Episode: 601 Total reward: 210
# Episode: 602 Total reward: 90
# Episode: 603 Total reward: 90
# Episode: 604 Total reward: 210
# Episode: 605 Total reward: 75
# Episode: 606 Total reward: 210
# Episode: 607 Total reward: 210
# Episode: 608 Total reward: 210
# Episode: 609 Total reward: 210
# Episode: 610 Total reward: 210
# Episode: 611 Total reward: 210
# Episode: 612 Total reward: 90
# Episode: 613 Total reward: 210
# Episode: 614 Total reward: 90
# Episode: 615 Total reward: 75
# Episode: 616 Total reward: 210
# Episode: 617 Total reward: 80
# Episode: 618 Total reward: 210
# Episode: 619 Total reward: 210
# Episode: 620 Total reward: 80
# Episode: 621 Total reward: 75
# Episode: 622 Total reward: 210
# Episode: 623 Total reward: 75
# Episode: 624 Total reward: 210
# Episode: 625 Total reward: 210
# Episode: 626 Total reward: 210
# Episode: 627 Total reward: 210
# Episode: 628 Total reward: 210
# Episode: 629 Total reward: 210
# Episode: 630 Total reward: 90
# Episode: 631 Total reward: 210
# Episode: 632 Total reward: 210
# Episode: 633 Total reward: 210
# Episode: 634 Total reward: 210
# Episode: 635 Total reward: 210
# Episode: 636 Total reward: 210
# Episode: 637 Total reward: 90
# Episode: 638 Total reward: 210
# Episode: 639 Total reward: 210
# Episode: 640 Total reward: 90
# Episode: 641 Total reward: 210
# Episode: 642 Total reward: 210
# Episode: 643 Total reward: 80
# Episode: 644 Total reward: 75
# Episode: 645 Total reward: 75
# Episode: 646 Total reward: 210
# Episode: 647 Total reward: 210
# Episode: 648 Total reward: 210
# Episode: 649 Total reward: 210
# Episode: 650 Total reward: 210
# Episode: 651 Total reward: 210
# Episode: 652 Total reward: 210
# Episode: 653 Total reward: 210
# Episode: 654 Total reward: 210
# Episode: 655 Total reward: 210
# Episode: 656 Total reward: 210
# Episode: 657 Total reward: 210
# Episode: 658 Total reward: 110
# Episode: 659 Total reward: 90
# Episode: 660 Total reward: 210
# Episode: 661 Total reward: 210
# Episode: 662 Total reward: 80
# Episode: 663 Total reward: 210
# Episode: 664 Total reward: 210
# Episode: 665 Total reward: 210
# Episode: 666 Total reward: 210
# Episode: 667 Total reward: 210
# Episode: 668 Total reward: 210
# Episode: 669 Total reward: 210
# Episode: 670 Total reward: 210
# Episode: 671 Total reward: 210
# Episode: 672 Total reward: 210
# Episode: 673 Total reward: 90
# Episode: 674 Total reward: 210
# Episode: 675 Total reward: 210
# Episode: 676 Total reward: 210
# Episode: 677 Total reward: 210
# Episode: 678 Total reward: 90
# Episode: 679 Total reward: 90
# Episode: 680 Total reward: 210
# Episode: 681 Total reward: 210
# Episode: 682 Total reward: 210
# Episode: 683 Total reward: 210
# Episode: 684 Total reward: 210
# Episode: 685 Total reward: 210
# Episode: 686 Total reward: 75
# Episode: 687 Total reward: 90
# Episode: 688 Total reward: -45
# Episode: 689 Total reward: 210
# Episode: 690 Total reward: 80
# Episode: 691 Total reward: -10
# Episode: 692 Total reward: 80
# Episode: 693 Total reward: 210
# Episode: 694 Total reward: 90
# Episode: 695 Total reward: 210
# Episode: 696 Total reward: 210
# Episode: 697 Total reward: 80
# Episode: 698 Total reward: 80
# Episode: 699 Total reward: 75
# Episode: 700 Total reward: 210
# Episode: 701 Total reward: 90
# Episode: 702 Total reward: 210
# Episode: 703 Total reward: -25
# Episode: 704 Total reward: -60
# Episode: 705 Total reward: 210
# Episode: 706 Total reward: 210
# Episode: 707 Total reward: 210
# Episode: 708 Total reward: 210
# Episode: 709 Total reward: 210
# Episode: 710 Total reward: 210
# Episode: 711 Total reward: 210
# Episode: 712 Total reward: 75
# Episode: 713 Total reward: 210
# Episode: 714 Total reward: 80
# Episode: 715 Total reward: 80
# Episode: 716 Total reward: 210
# Episode: 717 Total reward: 210
# Episode: 718 Total reward: 210
# Episode: 719 Total reward: 110
# Episode: 720 Total reward: 210
# Episode: 721 Total reward: 210
# Episode: 722 Total reward: 210
# Episode: 723 Total reward: 80
# Episode: 724 Total reward: 80
# Episode: 725 Total reward: 75
# Episode: 726 Total reward: 210
# Episode: 727 Total reward: 210
# Episode: 728 Total reward: 75
# Episode: 729 Total reward: 210
# Episode: 730 Total reward: 75
# Episode: 731 Total reward: 210
# Episode: 732 Total reward: 210
# Episode: 733 Total reward: 210
# Episode: 734 Total reward: 210
# Episode: 735 Total reward: 75
# Episode: 736 Total reward: 210
# Episode: 737 Total reward: 210
# Episode: 738 Total reward: 75
# Episode: 739 Total reward: 210
# Episode: 740 Total reward: 210
# Episode: 741 Total reward: 90
# Episode: 742 Total reward: 210
# Episode: 743 Total reward: 210
# Episode: 744 Total reward: 80
# Episode: 745 Total reward: 210
# Episode: 746 Total reward: 75
# Episode: 747 Total reward: 210
# Episode: 748 Total reward: 90
# Episode: 749 Total reward: 210
# Episode: 750 Total reward: 210
# Episode: 751 Total reward: 210
# Episode: 752 Total reward: 210
# Episode: 753 Total reward: 90
# Episode: 754 Total reward: 75
# Episode: 755 Total reward: 75
# Episode: 756 Total reward: 80
# Episode: 757 Total reward: -155
# Episode: 758 Total reward: 210
# Episode: 759 Total reward: 210
# Episode: 760 Total reward: 210
# Episode: 761 Total reward: 210
# Episode: 762 Total reward: 210
# Episode: 763 Total reward: 210
# Episode: 764 Total reward: 210
# Episode: 765 Total reward: 210
# Episode: 766 Total reward: 210
# Episode: 767 Total reward: 210
# Episode: 768 Total reward: 210
# Episode: 769 Total reward: 210
# Episode: 770 Total reward: -60
# Episode: 771 Total reward: 210
# Episode: 772 Total reward: 210
# Episode: 773 Total reward: 80
# Episode: 774 Total reward: 90
# Episode: 775 Total reward: 210
# Episode: 776 Total reward: 210
# Episode: 777 Total reward: 210
# Episode: 778 Total reward: 210
# Episode: 779 Total reward: 210
# Episode: 780 Total reward: 210
# Episode: 781 Total reward: -55
# Episode: 782 Total reward: 210
# Episode: 783 Total reward: 80
# Episode: 784 Total reward: 210
# Episode: 785 Total reward: 210
# Episode: 786 Total reward: 210
# Episode: 787 Total reward: 210
# Episode: 788 Total reward: 210
# Episode: 789 Total reward: 90
# Episode: 790 Total reward: 210
# Episode: 791 Total reward: 210
# Episode: 792 Total reward: 210
# Episode: 793 Total reward: 210
# Episode: 794 Total reward: 210
# Episode: 795 Total reward: 210
# Episode: 796 Total reward: 210
# Episode: 797 Total reward: 210
# Episode: 798 Total reward: 210
# Episode: 799 Total reward: 210
# Episode: 800 Total reward: 210
# Episode: 801 Total reward: 210
# Episode: 802 Total reward: 210
# Episode: 803 Total reward: 210
# Episode: 804 Total reward: 210
# Episode: 805 Total reward: 210
# Episode: 806 Total reward: 210
# Episode: 807 Total reward: 210
# Episode: 808 Total reward: -55
# Episode: 809 Total reward: 90
# Episode: 810 Total reward: 80
# Episode: 811 Total reward: 210
# Episode: 812 Total reward: 210
# Episode: 813 Total reward: 80
# Episode: 814 Total reward: 210
# Episode: 815 Total reward: 210
# Episode: 816 Total reward: 210
# Episode: 817 Total reward: 210
# Episode: 818 Total reward: 210
# Episode: 819 Total reward: 210
# Episode: 820 Total reward: 210
# Episode: 821 Total reward: 210
# Episode: 822 Total reward: 90
# Episode: 823 Total reward: -25
# Episode: 824 Total reward: 210
# Episode: 825 Total reward: 210
# Episode: 826 Total reward: 210
# Episode: 827 Total reward: 210
# Episode: 828 Total reward: 210
# Episode: 829 Total reward: 210
# Episode: 830 Total reward: 80
# Episode: 831 Total reward: -40
# Episode: 832 Total reward: 90
# Episode: 833 Total reward: 210
# Episode: 834 Total reward: 210
# Episode: 835 Total reward: 210
# Episode: 836 Total reward: 210
# Episode: 837 Total reward: 210
# Episode: 838 Total reward: 210
# Episode: 839 Total reward: 210
# Episode: 840 Total reward: 80
# Episode: 841 Total reward: 90
# Episode: 842 Total reward: 210
# Episode: 843 Total reward: 210
# Episode: 844 Total reward: 210
# Episode: 845 Total reward: 90
# Episode: 846 Total reward: 210
# Episode: 847 Total reward: 210
# Episode: 848 Total reward: 80
# Episode: 849 Total reward: 210
# Episode: 850 Total reward: 210
# Episode: 851 Total reward: 210
# Episode: 852 Total reward: 210
# Episode: 853 Total reward: 210
# Episode: 854 Total reward: 210
# Episode: 855 Total reward: 210
# Episode: 856 Total reward: 80
# Episode: 857 Total reward: 210
# Episode: 858 Total reward: 90
# Episode: 859 Total reward: 210
# Episode: 860 Total reward: 210
# Episode: 861 Total reward: 90
# Episode: 862 Total reward: 210
# Episode: 863 Total reward: 210
# Episode: 864 Total reward: 210
# Episode: 865 Total reward: 210
# Episode: 866 Total reward: 210
# Episode: 867 Total reward: 80
# Episode: 868 Total reward: 210
# Episode: 869 Total reward: 80
# Episode: 870 Total reward: 210
# Episode: 871 Total reward: 210
# Episode: 872 Total reward: 80
# Episode: 873 Total reward: 210
# Episode: 874 Total reward: 210
# Episode: 875 Total reward: 90
# Episode: 876 Total reward: 80
# Episode: 877 Total reward: 210
# Episode: 878 Total reward: 80
# Episode: 879 Total reward: 210
# Episode: 880 Total reward: 210
# Episode: 881 Total reward: 210
# Episode: 882 Total reward: 90
# Episode: 883 Total reward: 210
# Episode: 884 Total reward: 210
# Episode: 885 Total reward: 210
# Episode: 886 Total reward: 210
# Episode: 887 Total reward: 75
# Episode: 888 Total reward: 210
# Episode: 889 Total reward: 210
# Episode: 890 Total reward: 210
# Episode: 891 Total reward: 80
# Episode: 892 Total reward: 210
# Episode: 893 Total reward: 110
# Episode: 894 Total reward: 210
# Episode: 895 Total reward: 210
# Episode: 896 Total reward: 75
# Episode: 897 Total reward: 210
# Episode: 898 Total reward: 210
# Episode: 899 Total reward: 90
# Episode: 900 Total reward: 75
# Episode: 901 Total reward: 210
# Episode: 902 Total reward: 210
# Episode: 903 Total reward: 90
# Episode: 904 Total reward: 210
# Episode: 905 Total reward: 210
# Episode: 906 Total reward: 80
# Episode: 907 Total reward: 210
# Episode: 908 Total reward: 210
# Episode: 909 Total reward: 210
# Episode: 910 Total reward: 75
# Episode: 911 Total reward: 210
# Episode: 912 Total reward: 210
# Episode: 913 Total reward: 210
# Episode: 914 Total reward: 90
# Episode: 915 Total reward: 210
# Episode: 916 Total reward: 210
# Episode: 917 Total reward: 210
# Episode: 918 Total reward: 210
# Episode: 919 Total reward: 210
# Episode: 920 Total reward: 90
# Episode: 921 Total reward: 210
# Episode: 922 Total reward: 210
# Episode: 923 Total reward: 75
# Episode: 924 Total reward: 210
# Episode: 925 Total reward: 210
# Episode: 926 Total reward: 210
# Episode: 927 Total reward: 210
# Episode: 928 Total reward: -45
# Episode: 929 Total reward: 210
# Episode: 930 Total reward: 210
# Episode: 931 Total reward: 210
# Episode: 932 Total reward: 210
# Episode: 933 Total reward: 210
# Episode: 934 Total reward: 90
# Episode: 935 Total reward: 90
# Episode: 936 Total reward: 210
# Episode: 937 Total reward: 90
# Episode: 938 Total reward: 210
# Episode: 939 Total reward: 210
# Episode: 940 Total reward: 210
# Episode: 941 Total reward: 75
# Episode: 942 Total reward: 210
# Episode: 943 Total reward: 210
# Episode: 944 Total reward: 90
# Episode: 945 Total reward: 210
# Episode: 946 Total reward: 75
# Episode: 947 Total reward: 210
# Episode: 948 Total reward: 210
# Episode: 949 Total reward: 210
# Episode: 950 Total reward: 75
# Episode: 951 Total reward: 210
# Episode: 952 Total reward: 210
# Episode: 953 Total reward: 210
# Episode: 954 Total reward: 210
# Episode: 955 Total reward: 210
# Episode: 956 Total reward: 210
# Episode: 957 Total reward: 80
# Episode: 958 Total reward: 90
# Episode: 959 Total reward: 210
# Episode: 960 Total reward: 210
# Episode: 961 Total reward: 210
# Episode: 962 Total reward: 210
# Episode: 963 Total reward: 210
# Episode: 964 Total reward: 210
# Episode: 965 Total reward: 210
# Episode: 966 Total reward: 80
# Episode: 967 Total reward: 210
# Episode: 968 Total reward: 75
# Episode: 969 Total reward: 210
# Episode: 970 Total reward: 90
# Episode: 971 Total reward: 75
# Episode: 972 Total reward: 75
# Episode: 973 Total reward: 210
# Episode: 974 Total reward: 90
# Episode: 975 Total reward: 210
# Episode: 976 Total reward: 210
# Episode: 977 Total reward: 80
# Episode: 978 Total reward: 210
# Episode: 979 Total reward: 210
# Episode: 980 Total reward: 210
# Episode: 981 Total reward: 210
# Episode: 982 Total reward: 90
# Episode: 983 Total reward: 90
# Episode: 984 Total reward: 75
# Episode: 985 Total reward: 210
# Episode: 986 Total reward: 210
# Episode: 987 Total reward: 210
# Episode: 988 Total reward: 210
# Episode: 989 Total reward: 75
# Episode: 990 Total reward: 210
# Episode: 991 Total reward: 210
# Episode: 992 Total reward: 210
# Episode: 993 Total reward: 210
# Episode: 994 Total reward: 210
# Episode: 995 Total reward: 210
# Episode: 996 Total reward: 90
# Episode: 997 Total reward: 210
# Episode: 998 Total reward: 210
# Episode: 999 Total reward: 75

# %%
total_distance = test_vrp_agent(q_table, num_vehicles, capacity, customers, distance_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 total_distance = test_vrp_agent(q_table, num_vehicles, capacity, customers, distance_matrix)
#
# Input In [90], in test_vrp_agent(q_table, num_vehicles, capacity, customers, distance_matrix, num_episodes, alpha, gamma, epsilon)
#      19 reward = 0
#      20 if next_state in unvisited_nodes:
#      21     # Calculate the load and distance for the state transition
# ---> 22     load += customers[next_state]
#      23     if load > capacity:
#      24         reward = -1  # Exceeding capacity is penalized
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'tuple'
